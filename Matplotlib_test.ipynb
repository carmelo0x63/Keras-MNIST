# %%
import numpy as np
import os
os.environ["KERAS_BACKEND"] = "jax"
import keras

# %%
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
image = test_images[27]
plt.imshow(image)

# %%
test_labels[27]
# Out:
# np.uint8(4)
